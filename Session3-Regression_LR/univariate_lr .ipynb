# %% [markdown]
# ## ML session 2
# ### LINEAR REGRESSION
#
#
# Dataset given to you goes with the name 'population.txt'<br/>
# Dimension of the dataset is 97*2<br/>
# The columns are 'POPULATION' and  'PROFIT'<br/>
# In this session , we will try to predict profit for a new population.<br/>
# And hence we try to fit the dataset (curve fitting)<br/>
#
#
# Now lets visualise the data!!

# %%
import os  
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt

# %%
file ='population.txt'
data = pd.read_csv(file, header=None, names=['Population', 'Profit'])  
data.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
data.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
data.plot(kind='scatter', x='Population', y='Profit', figsize=(12,8))

# %% [markdown]
# #### COST FUNCTION:
#
# we have discussed the formula for cost function,<br/>
# Now lets implement it in pyhton.

# %%
def computeCost(X, y, param):  
    '''
    X--- set of inputs , a numpy array
    y--- set of actual outputs, a numpy array
    param--- a list containing values b,W in order
    '''
   #enter your code here

# %% [markdown]
# Lets see if u have coded properly
#
# Run the cell below and lets us know the answer

# %%
X=np.array([1, 2, 3])
y=np.array([1, 2, 3])
param=[1,1]
computeCost(X,y,param)

# %% [markdown]
# #### VECTORIZATION:
#
# Since we taught you why to use vectorization, we will look at some proof

# %%
from timeit import Timer

li = list(range(500000))
nump_arr = np.array(li)

def python_for():
    return [num + 1 for num in li]

def numpy_add():
    return nump_arr + 1

print(min(Timer(python_for).repeat(10, 10)))
print(min(Timer(numpy_add).repeat(10, 10)))

# %% [markdown]
# Now we shall convert our old dataset to a form suitable for vectorization
#
# append a column of ones at the begining of the dataset. The reason for it will be taught in class

# %%
data.insert(0, 'Ones', 1)

# %% [markdown]
# now the dataset looks like this

# %%
data.head()

# %% [markdown]
# we shall separate the input variable value and the target value using pandas.

# %%
#enter the code here .
#output has to have two lists: X-- input variables only
#                              y-- output / target variable

# %% [markdown]
# Lets see if u have done it correctly. Run the cell below and tell the answer

# %%
X = np.matrix(X.values)  
y = np.matrix(y.values)  
param = np.matrix(np.array([0,0])) 
X.shape, param.shape, y.shape

# %% [markdown]
#  Now code the new cost function using the formula taught to you in class

# %%
def computeCost1(X, y, param):
    '''
    X--- set of inputs , a numpy array of shape (97, 2)
    y--- set of actual outputs, a numpy array of shape (1, 2)
    param--- numpy array of shape (97, 1)
    '''
    #enter the code here

# %% [markdown]
# Lets check your code , run the cell below

# %%
computeCost1(X, y, param)

# %% [markdown]
# ### Thank you for your patience!! All the best!!
