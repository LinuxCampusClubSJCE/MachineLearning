# %% [markdown]
# # WHY DATA VISUALIZATION
#
#      IT ALLOWS US TO QUICKLY INTERPRET THE DATA AND ADJUST DIFFERENT VARIABLES TO SEE THEIR EFFECT
#
#      ALSO PROVEN THAT VISUAL INFORMATION IS MORE EFFECTIVE THAN TEXTUAL OR NUMERICAL INFORMATION
#
#      EASY TO CONVINCE PEOPLE

# %% [markdown]
# ![alt text](d1.png "Title")

# %% [markdown]
# # WHAT IS DATA VISUALIZATION
#
#    IT IS THE PROCESS OF REPRESENTING THE DATA IN PICTORIAL FORMAT

# %% [markdown]
# ![alt text](d2.png "Title")

# %% [markdown]
# In data visualization, there are three main types of variables:
#
# 1.Quantitative: These are numerical data and represent a measurement. Quantitative variables can be discrete (e.g., units sold in 2016) or continuous (e.g., average units sold per person).
#
# 2.Categorical: The values of these variables are names or labels. There is no inherent ordering to the labels. Examples of such variables are countries in a sales database and the names of products.
#
# 3.Ordinal: Variables that can take on values that are ranked on an arbitrary numerical scale. The numerical index associated with each value has no meaning except to rank the values relative to each other. Examples include days of the week, levels of satisfaction (not satisfied, satisfied, very satisfied), and customer value (low, medium, high).

# %% [markdown]
# ## WE USE MATPLOTLIB AND SEABORN FOR DATA VISUALIZATION FOR TODAYS SESSION
#
#      To install run the following commands in Anaconda Command Prompt
#
#      conda install matplotlib
#      conda install seaborn
#
# ## GETTING STARTED WITH MATPLOTLIB

# %%
# importing matplotlib from pyplot

import matplotlib.pyplot as plt

# for getting all figures inside the notebook

# %matplotlib inline

'''
This is a multiline
comment. I can type here whatever I want.
'''
# Out:
# '\nThis is a multiline\ncomment. I can type here whatever I want.\n'

# %% [markdown]
# ## if you are using another editor, you'll use: plt.show() at the end of all your plotting commands to have the figure pop up in another window

# %% [markdown]
# ## Now that we have the preliminaries out the way, we're ready to draw our first plot using matplotlib. In matplotlib, drawing a plot involves:
#     1.Creating a Figure to draw plots into.
#
#     2.Creating one or more Axes objects to draw the plots.
#
#     3.Showing the figure, and any plots inside, as an image.

# %%
import numpy as np
x = np.linspace(0, 5, 11)

y = x ** 2 + z**2

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y
# Out:
# array([  0. ,   0.5,   2. ,   4.5,   8. ,  12.5,  18. ,  24.5,  32. ,
#         40.5,  50. ])

# %%
z
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
plt.plot(z, y, 'g*') # 'r' is the color red
plt.xlabel('X Axis Title will beHere')
plt.ylabel('Y Axis Title will be Here')
plt.title('Entire Graph Title Here')
#plt.show()
# Out:
# Text(0.5,1,'Entire Graph Title Here')

# %% [markdown]
# ## Matplotlib Object Oriented Method
#
#     Now that we've seen the basics, let's break it all down with a more formal introduction of Matplotlib's Object Oriented API. This means we will instantiate figure objects and then call methods or attributes from that object
#
#     The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
#     To begin we create a figure instance. Then we can add axes to that figure

# %%
# Create Figure (empty canvas)
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5,1,'Set Title')

# %% [markdown]
# Code is a little more complicated, but the advantage is that we now have full control of where the plot axes are placed, and we can easily add more than one axis to the figure

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes1')
axes1.set_ylabel('Y_label_axes1')
axes1.set_title('Axes 1 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# ## subplots()
#
# The plt.subplots() object will act as a more automatic axis manager in the sense you need not explicitly specify axis parametres it will adjust automatically to itself.
#
# Basic use cases:

# %%
# creating figure object

fig,axes = plt.subplots()

# Now use the axes object to add stuff to plot
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
# Out:
# Text(0.5,1,'title')

# %% [markdown]
# Then you can specify the number of rows and columns when creating the subplots() object:

# %%
# Empty canvas of 1 by 2 subplots
fig, axes = plt.subplots(nrows=1, ncols=2)

# axes is an array so we can iterate through the array and we can plot each figure seperately
#  or since its an array you can plot using its index
for cur_ax in axes:
    cur_ax.plot(x,y)
    cur_ax.set_xlabel('x axis')
    cur_ax.set_ylabel('y axis')
 
# if we make nrows=2,ncols=2
#axes[0][0].plot(x,y)
#axes[0][1].plot(y,x)
#axes[1][0].plot(y,x)
#axes[1][1].plot(x,x)
    
plt.tight_layout()

# %% [markdown]
# ## BAR GRAPH
#     mainly used when we want to quickly understand trends between different variables

# %% [markdown]
# ## COMPARISON ACROSS CATEGORIES
# ![alt text](d6.png "Title")

# %% [markdown]
# ## COMPARISON ACROSS QUANTITATIVE DATA
# ![alt text](d7.png "Title")

# %%
Languages = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']
y_pos = np.arange(len(Languages))
performance = [10,8,6,4,2,1]


plt.bar(y_pos, performance, align='center')
plt.xticks(y_pos,Languages)
plt.ylabel('Usage')
plt.title('Programming language usage 2017')
 
#plt.show()
# Out:
# Text(0.5,1,'Programming language usage 2017')

# %% [markdown]
# ## MAKE LINEPLOT AS EXERCISE

# %% [markdown]
# # For Comparision

# %%
plt.bar([1,3,5,7,9],[5,2,7,8,2], label="Example one")

plt.bar([2,4,6,8,10],[8,6,2,5,6], label="Example two", color='g')
plt.legend()
plt.xlabel('bar number')
plt.ylabel('bar height')

plt.title('Epic Graph')

plt.show()

# %% [markdown]
# HISTOGRAM AND SCATTER PLOT WE WILL COVER IN SEABORN AS ITS MORE EFFICIANT AND GOOD LOOKING THAN MATPLOTLIB

# %% [markdown]
# ## STACK PLOT
#
#     USED FOR COMPARING MULTIPLE VARIABLES INSIDE THE SINGLE GRAPH

# %%
# create a days list
days = [1,2,3,4,5]

# categories for stacking
sleeping = [7,8,6,11,7]
eating = [2,3,4,3,2]
working = [7,8,7,2,2]
playing = [8,5,7,8,13]

plt.plot([],[],color='m',linewidth=5,label='sleeping')
plt.plot([],[],color='c',linewidth=5,label='eating')
plt.plot([],[],color='r',linewidth=5,label='working')
plt.plot([],[],color='y',linewidth=5,label='playing')

plt.stackplot(days,sleeping,eating,working,playing,colors=['m','c','r','y'])

plt.xlabel('Days')
plt.ylabel('Work Done')
plt.title('Stack plot')
plt.legend()

# %% [markdown]
# ## PIE CHART
#
#     MAINLY USED TO ANALYSE PERCENTAGE CONTRIBUTION AMONG VARIABLES

# %% [markdown]
# ![alt text](d8.png "Title")

# %%
# define labels
labels = ['Python','Kotlin','Java','C#']
# define sizes
sizes = [45,30,15,10]
# define which part to explode
explode = (0.1,0,0,0)

plt.pie(sizes,explode=explode,labels=labels,autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()
